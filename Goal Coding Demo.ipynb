# %% [markdown]
# ## Objectives
# #### Make notebooks more readable
# #### Encapsulate best of class approaches
# #### Make high level actions discoverable
# #### Easily switching the display between 2 modes: notebook development vs. final
# Development: where it's useful to see the result of each action
# Release: the checks shouldn't be displayed so the notebook is easier to read

# %%
from src.goal_coding import GoalCoding

# %% [markdown]
# ### Setup
# Initialize a GoalCoding instance, load a file into a Pandas dataframe

# %%
# %reload_ext autoreload
g = GoalCoding(
    file_or_object='data/Train.zip',
    its_name = 'train_df',
    nb_rows_to_read=100,
    debug_head=2) # number of lines of debug; 0 to turn debug off

# %% [markdown]
# #### All notebook objects are grouped into one
# Keeps the notebook tidy
# Allows for easy iteration over notebook objects

# %%
g.my_objects.print_info()
# Out:
# Your objects:
# Name: train_df , Type: <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# ### Improve readibility, capture best of class approach, discoverability through tabbing
# #### Ex: EDA in one line

# %%
g.eda.in_depth()
# Out:
# ### Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 53 columns):
# SalesID                     100 non-null int64
# SalePrice                   100 non-null int64
# MachineID                   100 non-null int64
# ModelID                     100 non-null int64
# datasource                  100 non-null int64
# auctioneerID                100 non-null int64
# YearMade                    100 non-null int64
# MachineHoursCurrentMeter    100 non-null int64
# UsageBand                   88 non-null object
# saledate                    100 non-null object
# fiModelDesc                 100 non-null object
# fiBaseModel                 100 non-null object
# fiSecondaryDesc             63 non-null object
# fiModelSeries               15 non-null object
# fiModelDescriptor           22 non-null object
# ProductSize                 46 non-null object
# fiProductClassDesc          100 non-null object
# ...

# %% [markdown]
# ### DEV mode; implicitly use the current object

# %%
g.configure.set_visual_check(debug_head=3)
_ = g.subset_rows.meet_logical_criteria(g.current['SalesID'] > 1139545)

# Lines below: 
# display of the syntax, to help learn it
# display of computation results
# Out:
# df_or_series_or_np_array[condition_or_filter_for_samples_to_keep]
#    SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  YearMade  \
# 0  1139246      66000     999089     3157         121             3      2004
# 1  1139248      57000     117657       77         121             3      1996
# 2  1139249      10000     434808     7009         121             3      2001
#
#    MachineHoursCurrentMeter UsageBand         saledate  ...  \
# 0                        68       Low  11/16/2006 0:00  ...
# 1                      4640       Low   3/26/2004 0:00  ...
# 2                      2838      High   2/26/2004 0:00  ...
#
#   Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 0                     NaN          NaN   NaN             NaN          NaN
# 1                     NaN          NaN   NaN             NaN          NaN
# 2                     NaN          NaN   NaN             NaN          NaN
#
# ...

# %% [markdown]
# ### PROD mode

# %%
g.configure.set_visual_check(debug_head=0)  # PROD mode, no debug display
_ = g.subset_rows.meet_logical_criteria(g.current['SalesID'] > 1139545)

# Nothing is printed below

# %% [markdown]
# ### You can still perform actions on objects as usual

# %%
g.o['train_df'].head(3)
# Out:
#     SalesID  SalePrice  MachineID  ModelID  datasource  auctioneerID  \
# 97  1139546      64000    1031217     4789         121             3
# 98  1139547      20500     332277     1571         121             3
# 99  1139550      27000      62171    13776         121             3
#
#     YearMade  MachineHoursCurrentMeter UsageBand        saledate  ...  \
# 97      2002                      5516    Medium  9/18/2008 0:00  ...
# 98      1980                         0       NaN  11/3/2005 0:00  ...
# 99      2000                      2842    Medium   6/1/2006 0:00  ...
#
#    Undercarriage_Pad_Width Stick_Length Thumb Pattern_Changer Grouser_Type  \
# 97                     NaN          NaN   NaN             NaN          NaN
# 98                     NaN          NaN   NaN             NaN          NaN
# 99                     NaN          NaN   NaN             NaN          NaN
#
#        Backhoe_Mounting           Blade_Type      Travel_Controls  \
# ...

# %% [markdown]
# ## Potential improvements
# ### Implement an 'exec' method to execute any existing Python, Pandas, etc. function on the current object
# Example: g.exec(g.current.map(lambda x: str(x))
# Benefits:
# * Debug output display still managed by g instance configuration: easy switch between dev and release notebook modes
# * Objects still managed by g instance: keeps the notebook higher level
#
# ### Simplify object access by creating the object dictionary in the notebook
# o = {}
# g = GoalCoding(o, 'data/Train.zip', 'train_df',100,2)  # pass the dict to the class
# o['train_df'].head(3)
